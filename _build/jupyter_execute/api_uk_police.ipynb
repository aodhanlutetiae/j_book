# %% [markdown]
# ## UK police API
#
# > source: https://data.police.uk/docs/

# %%
import requests

import pandas as pd
# pd.options.display.max_columns = 200

# %% [markdown]
# ## parameters
#
#     - Availability
#
#     Forces
#     Specific force
#     Force senior officers
#
#     Street level crimes
#     Street level outcomes
#     Crimes at location
#     Crimes with no location
#     Crime categories
#     Last updated
#     Outcomes for a specific crime
#
#     Neighbourhoods
#     Specific neighbourhood
#     Neighbourhood boundary
#     Neighbourhood team
#     Neighbourhood events
#     Neighbourhood priorities
#     Locate neighbourhood
#
#     Stop and searches by area
#     - Stop and searches by location
#     Stop and searches with no location
#     Stop and searches by force

# %% [markdown]
# ## Availability -- last 3 years (36 months)

# %%
# returns list of all available datasets

url = 'https://data.police.uk/api/crimes-street-dates'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
# data from earliest month
print(req.json()[35]['date'])

# data from latest month
print(req.json()[0]['date'])
# Out:
# 2018-06
# 2021-05

# %% [markdown]
# ## Stop and search

# %%
# send query via variables and f-string

endpoint = 'https://data.police.uk/api'
method = 'stops-street'
lat = "52.629729"
long = "-1.131592"
month = "2021-04"

query = f'{endpoint}/{method}?lat={lat}&lng={long}&date={month}'
print(query)

req = requests.get(query)
req
# Out:
# https://data.police.uk/api/stops-street?lat=52.629729&lng=-1.131592&date=2021-04
# <Response [200]>

# %%
req.json()
# Out:
# [{'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-07T19:55:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626988',
#    'street': {'id': 882307,
#     'name': 'On or near Further/Higher Educational Building'},
#    'longitude': '-1.123532'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-17T18:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-22T22:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-21T23:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-21T23:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T21:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633161',
#    'street': {'id': 883433, 'name': 'On or near Castle Street'},
#    'longitude': '-1.140416'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T12:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.630546',
#    'street': {'id': 883338, 'name': 'On or near Norton Street'},
#    'longitude': '-1.134261'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T12:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630546',
#    'street': {'id': 883338, 'name': 'On or near Norton Street'},
#    'longitude': '-1.134261'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T12:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630546',
#    'street': {'id': 883338, 'name': 'On or near Norton Street'},
#    'longitude': '-1.134261'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T05:17:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633655',
#    'street': {'id': 883217, 'name': 'On or near Maidstone Road'},
#    'longitude': '-1.118286'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T21:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633161',
#    'street': {'id': 883433, 'name': 'On or near Castle Street'},
#    'longitude': '-1.140416'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-17T17:39:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.637830',
#    'street': {'id': 883465, 'name': 'On or near Vernon Street'},
#    'longitude': '-1.149501'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-17T07:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.634693',
#    'street': {'id': 883424, 'name': 'On or near St Nicholas Circle'},
#    'longitude': '-1.140799'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-17T00:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-20T11:48:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.631564',
#    'street': {'id': 883395, 'name': 'On or near Theatre/Concert Hall'},
#    'longitude': '-1.129661'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-24T12:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633937',
#    'street': {'id': 883495, 'name': 'On or near King Richards Road'},
#    'longitude': '-1.152029'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T12:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.629835',
#    'street': {'id': 883303, 'name': 'On or near Parking Area'},
#    'longitude': '-1.133005'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T18:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.631611',
#    'street': {'id': 883264, 'name': 'On or near Slate Street'},
#    'longitude': '-1.122612'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T18:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631611',
#    'street': {'id': 883264, 'name': 'On or near Slate Street'},
#    'longitude': '-1.122612'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-29T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.625507',
#    'street': {'id': 882479, 'name': 'On or near Chaucer Street'},
#    'longitude': '-1.113013'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-28T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.637414',
#    'street': {'id': 883138, 'name': 'On or near Hart Road'},
#    'longitude': '-1.113600'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637414',
#    'street': {'id': 883138, 'name': 'On or near Hart Road'},
#    'longitude': '-1.113600'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.637414',
#    'street': {'id': 883138, 'name': 'On or near Hart Road'},
#    'longitude': '-1.113600'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T18:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.631611',
#    'street': {'id': 883264, 'name': 'On or near Slate Street'},
#    'longitude': '-1.122612'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-29T19:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.635005',
#    'street': {'id': 883219, 'name': 'On or near Jupiter Close'},
#    'longitude': '-1.117284'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-27T08:05:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635414',
#    'street': {'id': 883313, 'name': 'On or near Yeoman Street'},
#    'longitude': '-1.128742'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-29T17:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Asian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-29T17:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-28T23:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.624424',
#    'street': {'id': 882275, 'name': 'On or near Stuart Street'},
#    'longitude': '-1.150485'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-29T17:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-24T08:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.638770',
#    'street': {'id': 883283, 'name': 'On or near Brunswick Street'},
#    'longitude': '-1.121893'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-25T13:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.624424',
#    'street': {'id': 882275, 'name': 'On or near Stuart Street'},
#    'longitude': '-1.150485'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Any other ethnic group',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-25T13:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.624424',
#    'street': {'id': 882275, 'name': 'On or near Stuart Street'},
#    'longitude': '-1.150485'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-24T12:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633937',
#    'street': {'id': 883495, 'name': 'On or near King Richards Road'},
#    'longitude': '-1.152029'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-26T08:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.634136',
#    'street': {'id': 883357, 'name': 'On or near Hotel Street'},
#    'longitude': '-1.134752'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-27T17:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.637744',
#    'street': {'id': 883499, 'name': 'On or near Jarvis Street'},
#    'longitude': '-1.142616'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Irish',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-27T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.632246',
#    'street': {'id': 883311, 'name': 'On or near York Street'},
#    'longitude': '-1.129529'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-26T09:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635062',
#    'street': {'id': 883289, 'name': 'On or near Gallowtree Gate'},
#    'longitude': '-1.132222'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-26T12:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-26T09:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.636250',
#    'street': {'id': 883415, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.133691'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-09T14:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.638556',
#    'street': {'id': 883349, 'name': 'On or near Mansfield Street'},
#    'longitude': '-1.133113'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-04T04:07:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.642180',
#    'street': {'id': 884424, 'name': 'On or near Kashmir Road'},
#    'longitude': '-1.119859'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-04T03:57:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.642180',
#    'street': {'id': 884424, 'name': 'On or near Kashmir Road'},
#    'longitude': '-1.119859'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-08T20:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635290',
#    'street': {'id': 883517, 'name': 'On or near Clifford Street'},
#    'longitude': '-1.148856'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-09T20:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Irish',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-09T21:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-09T14:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.638556',
#    'street': {'id': 883349, 'name': 'On or near Mansfield Street'},
#    'longitude': '-1.133113'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-07T19:53:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.640715',
#    'street': {'id': 884342, 'name': 'On or near Wood Street'},
#    'longitude': '-1.130854'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-07T19:55:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.640715',
#    'street': {'id': 884342, 'name': 'On or near Wood Street'},
#    'longitude': '-1.130854'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-07T12:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.620842',
#    'street': {'id': 876361, 'name': 'On or near Counting House Road'},
#    'longitude': '-1.131306'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-04T03:57:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.642180',
#    'street': {'id': 884424, 'name': 'On or near Kashmir Road'},
#    'longitude': '-1.119859'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-09T22:40:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.640715',
#    'street': {'id': 884342, 'name': 'On or near Wood Street'},
#    'longitude': '-1.130854'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-09T22:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.640715',
#    'street': {'id': 884342, 'name': 'On or near Wood Street'},
#    'longitude': '-1.130854'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-08T23:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629835',
#    'street': {'id': 883303, 'name': 'On or near Parking Area'},
#    'longitude': '-1.133005'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-06T08:40:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630187',
#    'street': {'id': 883281, 'name': 'On or near College Street'},
#    'longitude': '-1.120956'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-14T13:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.621978',
#    'street': {'id': 882348, 'name': 'On or near Sports/Recreation Area'},
#    'longitude': '-1.138005'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-10T00:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-15T15:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.626534',
#    'street': {'id': 882277, 'name': 'On or near Sage Road'},
#    'longitude': '-1.145096'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-15T15:52:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-14T13:05:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.621978',
#    'street': {'id': 882348, 'name': 'On or near Sports/Recreation Area'},
#    'longitude': '-1.138005'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-13T16:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.631238',
#    'street': {'id': 883210, 'name': 'On or near Sparkenhoe Street'},
#    'longitude': '-1.119635'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-01T18:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.636110',
#    'street': {'id': 883290, 'name': 'On or near Humberstone Gate'},
#    'longitude': '-1.131802'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
# ...
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628804',
#    'street': {'id': 883331, 'name': 'On or near Rawson Street'},
#    'longitude': '-1.129716'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-01T18:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.636110',
#    'street': {'id': 883290, 'name': 'On or near Humberstone Gate'},
#    'longitude': '-1.131802'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-03T23:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629293',
#    'street': {'id': 1319949, 'name': 'On or near Bede Park'},
#    'longitude': '-1.144983'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-03T15:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635767',
#    'street': {'id': 883291, 'name': 'On or near High Street'},
#    'longitude': '-1.135267'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-03T14:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635184',
#    'street': {'id': 883410, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.135455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-03T14:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635184',
#    'street': {'id': 883410, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.135455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-03T14:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635184',
#    'street': {'id': 883410, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.135455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-06T14:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633190',
#    'street': {'id': 883104, 'name': 'On or near Pluto Close'},
#    'longitude': '-1.116168'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-28T21:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.635121',
#    'street': {'id': 883430, 'name': 'On or near High Street'},
#    'longitude': '-1.139077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-02T23:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633540',
#    'street': {'id': 883379, 'name': 'On or near Church Street'},
#    'longitude': '-1.126977'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-07T14:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626534',
#    'street': {'id': 882277, 'name': 'On or near Sage Road'},
#    'longitude': '-1.145096'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-22T13:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635767',
#    'street': {'id': 883291, 'name': 'On or near High Street'},
#    'longitude': '-1.135267'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-11T15:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628757',
#    'street': {'id': 883461, 'name': 'On or near Western Boulevard'},
#    'longitude': '-1.143043'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-13T23:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.629797',
#    'street': {'id': 883332, 'name': 'On or near Princess Road Backways'},
#    'longitude': '-1.130272'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-26T17:16:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635414',
#    'street': {'id': 883313, 'name': 'On or near Yeoman Street'},
#    'longitude': '-1.128742'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-24T23:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.623932',
#    'street': {'id': 882310, 'name': 'On or near Parking Area'},
#    'longitude': '-1.142148'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Offensive weapons'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2021-04-26T19:44:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626564',
#    'street': {'id': 882382, 'name': 'On or near Granville Road'},
#    'longitude': '-1.118606'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2021-04-01T19:25:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-08T10:41:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-08T10:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2021-04-29T13:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'}]

# %%
# query via assembled url (bicycle theft, April 2021)

epoint = 'https://data.police.uk/api/crimes-street/bicycle-theft?lat=51.476369992679096&lng=-3.1781098361443667&date=2021-04'

req = requests.get(epoint)
req
# Out:
# <Response [200]>

# %%
response = req.json()

# %%
len(response)
# Out:
# 34

# %%
response
# Out:
# [{'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.485384',
#    'street': {'id': 1081176, 'name': 'On or near The Walk'},
#    'longitude': '-3.169447'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'b690e717ff1e48bd1b15ad8055a648c62d3ba5956a25a70fdc4f116218719902',
#   'id': 92090274,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.470725',
#    'street': {'id': 1080153, 'name': 'On or near Blaenclydach Street'},
#    'longitude': '-3.183110'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '236d848efd588e920a356ea33cd81b64815f3b8d743904e771b6b5410389a120',
#   'id': 92090234,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.488790',
#    'street': {'id': 1081578, 'name': 'On or near Lowther Road'},
#    'longitude': '-3.173265'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '7e11a9e36a079b99862d4d02878db72cd931fd91bff185a0f43823477caefe75',
#   'id': 92090315,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.470514',
#    'street': {'id': 1080170, 'name': 'On or near Blaenclydach Place'},
#    'longitude': '-3.182601'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '59afc4ae357dc95426f73f6f9e54ebeb2302d6dbcdc1dce6eef2c0dcae31275b',
#   'id': 92090305,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.479362',
#    'street': {'id': 1080938, 'name': 'On or near Wharton Street'},
#    'longitude': '-3.178178'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '8da28c42dd7e058fe7b587aaf8690ef14faf96a60482c08c65b3e59aae8c8f90',
#   'id': 92090304,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.476106',
#    'street': {'id': 1081078, 'name': 'On or near Wood Street'},
#    'longitude': '-3.182745'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '3ec81c2d77ee882feec175c8feca95256ebf8d1fea1dce9e2014630eedad43d5',
#   'id': 92090309,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.481807',
#    'street': {'id': 1081225, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.174655'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '9bc2c435f047689b9bf31b909e603c6234b8d7bb977a93e8d2b08914cf55b6f8',
#   'id': 92090296,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.471385',
#    'street': {'id': 1080181, 'name': 'On or near Curran Road'},
#    'longitude': '-3.176518'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '4ce6e6a4e603a7add093d4535d59e15df91ae29e9a5495d83647900a555c2b5a',
#   'id': 92090293,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.483169',
#    'street': {'id': 1081224, 'name': 'On or near Nightclub'},
#    'longitude': '-3.175166'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'c5efab538cc6e0f87080dec2be25b5e361e2db634fd86d64c9ad6ff528202a2e',
#   'id': 92090294,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.465215',
#    'street': {'id': 1080058, 'name': 'On or near Mount Stuart Square'},
#    'longitude': '-3.167708'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '0ee3c70a426725ad98358f42aa6548a60148c18ecda127578849b24bd24c3030',
#   'id': 92090299,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.480220',
#    'street': {'id': 1080962, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.176026'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '36593a5295bea191c484fa2cd7bafd647225f3f227a0a90a73da76efeb47fb4e',
#   'id': 92090281,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.465736',
#    'street': {'id': 1080084,
#     'name': 'On or near Further/higher Educational Building'},
#    'longitude': '-3.193634'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '9e2331402a5670b367ed7c92a303ceca0c3563db46e94de0bee3f4abbb518cac',
#   'id': 92090277,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.476010',
#    'street': {'id': 1081076, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.179762'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '4d2b3b4e432e8a3ff73427a805aa0c8ac35906bc579e0534cae61fdce379e50d',
#   'id': 92090280,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.476545',
#    'street': {'id': 1081059, 'name': 'On or near Petrol Station'},
#    'longitude': '-3.184715'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'e1bf814769eee368135aae0ebe6f3ee337b03d20df90308d175deb6569437eea',
#   'id': 92090286,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.465550',
#    'street': {'id': 1080013, 'name': 'On or near Heol Tredwen'},
#    'longitude': '-3.171934'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'c3604dd6214b76fa65628bbae5bffea5def023bb4ccc8a61e9d4526cf2b6d6bd',
#   'id': 92090276,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.466610',
#    'street': {'id': 1080027, 'name': 'On or near Chandlery Way'},
#    'longitude': '-3.172005'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '6433af2c1c79e227530d8b32407b237921c62ac6f409c45875dc5ea7f64b626f',
#   'id': 92090271,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.480034',
#    'street': {'id': 1081215, 'name': 'On or near Davis Street'},
#    'longitude': '-3.165782'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '68fbb105f0067f20c75a19f1fb1ce9cae301d2d0aa6d6782ef683c46613dd24f',
#   'id': 92090270,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.481140',
#    'street': {'id': 1080957, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.179290'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '05f1a8e4a75caf46fef814151a7b4633577a8e63235c077e3c44a187ad18e5fc',
#   'id': 92090268,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.477699',
#    'street': {'id': 1081075, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.176335'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '8228a96fde2c2aceca3474b797afdc205baccf4b97c59161cbcea796c09f9b02',
#   'id': 92090258,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.472643',
#    'street': {'id': 1080173, 'name': 'On or near Trade Street'},
#    'longitude': '-3.178365'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'd4e6f9c94ff4adb4b39655476ca541df26cdfbbbace41fe8223ff3cdc55f0804',
#   'id': 92090257,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.471385',
#    'street': {'id': 1080181, 'name': 'On or near Curran Road'},
#    'longitude': '-3.176518'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'eafc6fa0e2dde48a363422737ad4d514242fc891984219da077877f7b75cd332',
#   'id': 92090252,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.465313',
#    'street': {'id': 1080151, 'name': 'On or near Bromsgrove Street'},
#    'longitude': '-3.184755'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'ec30e5767b21465c231aa43244d8fb40647ee4207f243eddba58951e6950a91d',
#   'id': 92090255,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.480314',
#    'street': {'id': 1080949, 'name': 'On or near Nightclub'},
#    'longitude': '-3.179139'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'f676fe9152a8443d8e944377b274256523a3f5ce545a13c016b47706285535d1',
#   'id': 92090250,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.481550',
#    'street': {'id': 1080806, 'name': 'On or near Cowbridge Road East'},
#    'longitude': '-3.197402'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'f091d8c3563e7c564ac5149cb473ad6443c6ecebca91822b8f9f05855cb6e422',
#   'id': 92090240,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.479605',
#    'street': {'id': 1080950, 'name': 'On or near Nightclub'},
#    'longitude': '-3.177277'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '8c6facf488db0c56beeb67ca95a2145c38669260a1650275d879315bb50eb23e',
#   'id': 92090233,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.473919',
#    'street': {'id': 1080129, 'name': 'On or near Hafod Street'},
#    'longitude': '-3.183783'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '97b980bc7a2b43e4e7a7f4ecbfaa82286cdcb09e5a447796a9981622dbcbddae',
#   'id': 92090235,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.480913',
#    'street': {'id': 1080953, 'name': 'On or near Nightclub'},
#    'longitude': '-3.181286'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '07d982ec7b536f2eaa82c1e1df60b1d005a26f5113167182a163fe54cfc5e8b9',
#   'id': 92090224,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.482455',
#    'street': {'id': 1081199, 'name': 'On or near Moira Street'},
#    'longitude': '-3.162935'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'cf771126b45f84a55c31030a744111e291a3771d5671fbacea0a1283efa9b489',
#   'id': 92090221,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.489781',
#    'street': {'id': 1081695, 'name': 'On or near Colum Terrace'},
#    'longitude': '-3.183834'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'e0162610d8b111fb8ba016d492a03bd1997ef0a1c2482941025c243991d2320b',
#   'id': 92090220,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.481938',
#    'street': {'id': 1080764, 'name': 'On or near Parking Area'},
#    'longitude': '-3.198205'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '4a88824f31184db35a0b07969c3428d569c0b9e790e680e995cfbf7b9a5b3cdc',
#   'id': 92090217,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.477714',
#    'street': {'id': 1081069, 'name': 'On or near Havelock Street'},
#    'longitude': '-3.179302'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': 'a44d973b9b47f70ec6750ad26bccfa1e23a71a2dd88309783d5adf0fdfeb99bf',
#   'id': 92090209,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.476336',
#    'street': {'id': 1081054, 'name': 'On or near Clare Road'},
#    'longitude': '-3.187546'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': '82362ab89bab5341230f483578bd3172977663c92d5074783c8f4cc023948c8c',
#   'id': 92090210,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.488283',
#    'street': {'id': 1081590, 'name': 'On or near Byron Street'},
#    'longitude': '-3.166425'},
#   'context': '',
#   'outcome_status': {'category': 'Under investigation', 'date': '2021-04'},
#   'persistent_id': 'a132917affd5dda4ed7ff0fc038c9e2e1cf8ec56b822f48c63d88aec610a124a',
#   'id': 92090207,
#   'location_subtype': '',
#   'month': '2021-04'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '51.477699',
#    'street': {'id': 1081075, 'name': 'On or near Shopping Area'},
#    'longitude': '-3.176335'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2021-04'},
#   'persistent_id': '53188a55732ac2bad23de765866eb3946b8d17173a368a9128fb35cbd4a47b41',
#   'id': 92090307,
#   'location_subtype': '',
#   'month': '2021-04'}]

# %%
# first item in the response

response[0]
# Out:
# {'category': 'bicycle-theft',
#  'location_type': 'Force',
#  'location': {'latitude': '51.485384',
#   'street': {'id': 1081176, 'name': 'On or near The Walk'},
#   'longitude': '-3.169447'},
#  'context': '',
#  'outcome_status': {'category': 'Investigation complete; no suspect identified',
#   'date': '2021-04'},
#  'persistent_id': 'b690e717ff1e48bd1b15ad8055a648c62d3ba5956a25a70fdc4f116218719902',
#  'id': 92090274,
#  'location_subtype': '',
#  'month': '2021-04'}

# %% [markdown]
# ## using 'params' argument to supply dictionary of arguments

# %%
endpoint = 'https://data.police.uk/api/stops-street?'
parameters = {'lat':"52.629729", 'lng':"-1.131592", 'date':"2020-06"}

req = requests.get(endpoint, params = parameters)
req
# Out:
# <Response [200]>

# %%
response = req.json()

# %%
response
# Out:
# [{'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-12T21:04:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629909',
#    'street': {'id': 883345, 'name': 'On or near Marquis Street'},
#    'longitude': '-1.132073'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-01T02:16:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.633540',
#    'street': {'id': 883379, 'name': 'On or near Church Street'},
#    'longitude': '-1.126977'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-28T01:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.627524',
#    'street': {'id': 883450, 'name': 'On or near Cambridge Street'},
#    'longitude': '-1.153985'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-28T14:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635184',
#    'street': {'id': 883410, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.135455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-28T14:35:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.638556',
#    'street': {'id': 883349, 'name': 'On or near Mansfield Street'},
#    'longitude': '-1.133113'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-04T23:18:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.630562',
#    'street': {'id': 883531, 'name': 'On or near Parking Area'},
#    'longitude': '-1.153971'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-10T17:43:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.629909',
#    'street': {'id': 883345, 'name': 'On or near Marquis Street'},
#    'longitude': '-1.132073'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T14:20:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.641197',
#    'street': {'id': 884356, 'name': 'On or near A594'},
#    'longitude': '-1.129100'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-12T17:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.625507',
#    'street': {'id': 882479, 'name': 'On or near Chaucer Street'},
#    'longitude': '-1.113013'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Stolen goods'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-07T05:42:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632246',
#    'street': {'id': 883311, 'name': 'On or near York Street'},
#    'longitude': '-1.129529'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-11T04:46:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637674',
#    'street': {'id': 883469, 'name': 'On or near Tudor Road'},
#    'longitude': '-1.147819'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-10T13:57:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.641734',
#    'street': {'id': 884352, 'name': 'On or near Friday Street'},
#    'longitude': '-1.137336'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-08T13:07:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.625463',
#    'street': {'id': 882335, 'name': 'On or near Lancaster Road'},
#    'longitude': '-1.127684'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-10T19:47:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.627112',
#    'street': {'id': 882209, 'name': 'On or near Narborough Road'},
#    'longitude': '-1.150477'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-09T00:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628804',
#    'street': {'id': 883331, 'name': 'On or near Rawson Street'},
#    'longitude': '-1.129716'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-15T18:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633145',
#    'street': {'id': 883365, 'name': 'On or near Granby Street'},
#    'longitude': '-1.129511'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-11T21:04:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.635005',
#    'street': {'id': 883219, 'name': 'On or near Jupiter Close'},
#    'longitude': '-1.117284'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-15T03:46:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.620842',
#    'street': {'id': 876361, 'name': 'On or near Counting House Road'},
#    'longitude': '-1.131306'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': '',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-16T09:46:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': '', 'name': ''},
#   'location': {'latitude': '52.633347',
#    'street': {'id': 883387, 'name': 'On or near Berridge Street'},
#    'longitude': '-1.135034'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-15T19:21:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.633145',
#    'street': {'id': 883365, 'name': 'On or near Granby Street'},
#    'longitude': '-1.129511'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-03T02:06:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.627126',
#    'street': {'id': 882309, 'name': 'On or near Eastern Boulevard'},
#    'longitude': '-1.142455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-03T02:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.627126',
#    'street': {'id': 882309, 'name': 'On or near Eastern Boulevard'},
#    'longitude': '-1.142455'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-14T06:51:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.623521',
#    'street': {'id': 882292, 'name': 'On or near Eastleigh Road'},
#    'longitude': '-1.151167'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-14T06:59:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635414',
#    'street': {'id': 883313, 'name': 'On or near Yeoman Street'},
#    'longitude': '-1.128742'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-14T07:22:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635414',
#    'street': {'id': 883313, 'name': 'On or near Yeoman Street'},
#    'longitude': '-1.128742'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T09:19:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.634279',
#    'street': {'id': 883366, 'name': 'On or near Granby Place'},
#    'longitude': '-1.130922'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T10:29:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.634407',
#    'street': {'id': 883407, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.133653'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T11:58:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.634407',
#    'street': {'id': 883407, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.133653'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-06T00:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.620842',
#    'street': {'id': 876361, 'name': 'On or near Counting House Road'},
#    'longitude': '-1.131306'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-06T11:19:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.643544',
#    'street': {'id': 884317, 'name': 'On or near Wanlip Street'},
#    'longitude': '-1.125551'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-07T05:28:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632246',
#    'street': {'id': 883311, 'name': 'On or near York Street'},
#    'longitude': '-1.129529'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-07T05:42:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632246',
#    'street': {'id': 883311, 'name': 'On or near York Street'},
#    'longitude': '-1.129529'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-06T01:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626050',
#    'street': {'id': 882392, 'name': 'On or near Granville Road'},
#    'longitude': '-1.119606'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-21T06:36:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632755',
#    'street': {'id': 883511, 'name': 'On or near Duns Lane'},
#    'longitude': '-1.143837'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T21:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628588',
#    'street': {'id': 883223, 'name': 'On or near Gotham Street'},
#    'longitude': '-1.119910'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T21:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628588',
#    'street': {'id': 883223, 'name': 'On or near Gotham Street'},
#    'longitude': '-1.119910'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-21T00:35:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639814',
#    'street': {'id': 883235, 'name': 'On or near Sanvey Gate'},
#    'longitude': '-1.139118'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-25T20:00:00+00:00',
#   'removal_of_more_than_outer_clothing': True,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.637354',
#    'street': {'id': 883414, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.138383'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T18:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633655',
#    'street': {'id': 883217, 'name': 'On or near Maidstone Road'},
#    'longitude': '-1.118286'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-18T14:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.627396',
#    'street': {'id': 883417, 'name': 'On or near Ullswater Street'},
#    'longitude': '-1.141238'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-25T07:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.639814',
#    'street': {'id': 883235, 'name': 'On or near Sanvey Gate'},
#    'longitude': '-1.139118'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Any other Asian background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-20T01:11:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639332',
#    'street': {'id': 883327, 'name': "On or near St Margaret'S Way"},
#    'longitude': '-1.135906'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T23:35:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639566',
#    'street': {'id': 883325, 'name': 'On or near St Matthews Way'},
#    'longitude': '-1.126221'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T21:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628588',
#    'street': {'id': 883223, 'name': 'On or near Gotham Street'},
#    'longitude': '-1.119910'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T23:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639566',
#    'street': {'id': 883325, 'name': 'On or near St Matthews Way'},
#    'longitude': '-1.126221'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T23:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639566',
#    'street': {'id': 883325, 'name': 'On or near St Matthews Way'},
#    'longitude': '-1.126221'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-24T00:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626050',
#    'street': {'id': 882392, 'name': 'On or near Granville Road'},
#    'longitude': '-1.119606'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Arrest',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-25T20:33:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-arrest', 'name': 'Arrest'},
#   'location': {'latitude': '52.637354',
#    'street': {'id': 883414, 'name': 'On or near Shopping Area'},
#    'longitude': '-1.138383'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-25T17:07:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.621591',
#    'street': {'id': 882481, 'name': 'On or near Cedars Court'},
#    'longitude': '-1.113536'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Female',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-25T03:23:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633265',
#    'street': {'id': 883277, 'name': 'On or near Fox Street'},
#    'longitude': '-1.125106'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person and Vehicle search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-25T15:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.629797',
#    'street': {'id': 883332, 'name': 'On or near Princess Road Backways'},
#    'longitude': '-1.130272'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-24T00:15:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.626050',
#    'street': {'id': 882392, 'name': 'On or near Granville Road'},
#    'longitude': '-1.119606'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-26T17:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630684',
#    'street': {'id': 883373, 'name': 'On or near Dunkirk Street'},
#    'longitude': '-1.128659'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-26T17:51:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630684',
#    'street': {'id': 883373, 'name': 'On or near Dunkirk Street'},
#    'longitude': '-1.128659'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-26T17:45:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.630684',
#    'street': {'id': 883373, 'name': 'On or near Dunkirk Street'},
#    'longitude': '-1.128659'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T09:36:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633888',
#    'street': {'id': 883425, 'name': 'On or near Peacock Lane'},
#    'longitude': '-1.138924'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T12:18:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.633007',
#    'street': {'id': 883386, 'name': 'On or near Bowling Green Street'},
#    'longitude': '-1.132839'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T13:19:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.636243',
#    'street': {'id': 883321, 'name': 'On or near Vestry Street'},
#    'longitude': '-1.127810'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-23T13:43:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.633414',
#    'street': {'id': 876793, 'name': 'On or near Bishop Street'},
#    'longitude': '-1.131841'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-17T18:56:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637024',
#    'street': {'id': 883408, 'name': 'On or near Supermarket'},
#    'longitude': '-1.128962'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-17T19:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637024',
#    'street': {'id': 883408, 'name': 'On or near Supermarket'},
#    'longitude': '-1.128962'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-17T18:51:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.637024',
#    'street': {'id': 883408, 'name': 'On or near Supermarket'},
#    'longitude': '-1.128962'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Pakistani',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': None,
# ...
#    'street': {'id': 883104, 'name': 'On or near Pluto Close'},
#    'longitude': '-1.116168'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-11T18:14:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.636033',
#    'street': {'id': 883368, 'name': 'On or near Freeschool Lane'},
#    'longitude': '-1.138424'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-16T00:41:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': None,
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Other ethnic group - Not stated',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-16T00:41:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.639768',
#    'street': {'id': 883239, 'name': 'On or near Parking Area'},
#    'longitude': '-1.131597'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-05T16:30:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632107',
#    'street': {'id': 883528, 'name': 'On or near Police Station'},
#    'longitude': '-1.151311'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-22T15:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635121',
#    'street': {'id': 883430, 'name': 'On or near High Street'},
#    'longitude': '-1.139077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-22T15:50:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.635121',
#    'street': {'id': 883430, 'name': 'On or near High Street'},
#    'longitude': '-1.139077'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-21T19:40:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.628413',
#    'street': {'id': 883246, 'name': 'On or near Upper King Street'},
#    'longitude': '-1.131585'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': 'Community resolution',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Female',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T09:40:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-community-resolution',
#    'name': 'Community resolution'},
#   'location': {'latitude': '52.637600',
#    'street': {'id': 883324, 'name': 'On or near St Peters Lane'},
#    'longitude': '-1.135171'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-27T14:42:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632003',
#    'street': {'id': 883216, 'name': 'On or near Moon Close'},
#    'longitude': '-1.119753'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-11T16:10:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.636033',
#    'street': {'id': 883368, 'name': 'On or near Freeschool Lane'},
#    'longitude': '-1.138424'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Other',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': 'over 34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-19T14:23:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.625944',
#    'street': {'id': 882313, 'name': 'On or near Windermere Street'},
#    'longitude': '-1.140601'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-02T11:17:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.632883',
#    'street': {'id': 883538, 'name': 'On or near Stretton Road'},
#    'longitude': '-1.154148'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': None,
#   'datetime': '2020-06-19T14:11:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.625944',
#    'street': {'id': 882313, 'name': 'On or near Windermere Street'},
#    'longitude': '-1.140601'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - Any other White background',
#   'gender': 'Male',
#   'legislation': 'Police and Criminal Evidence Act 1984 (section 1)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-18T19:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Article for use in theft'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-19T16:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Asian/Asian British - Indian',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': False,
#   'datetime': '2020-06-19T16:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Asian',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '25-34',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - African',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2020-06-26T16:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '18-24',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Black/African/Caribbean/Black British - Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2020-06-26T17:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': '10-17',
#   'outcome': 'A no further action disposal',
#   'involved_person': True,
#   'self_defined_ethnicity': 'Mixed/Multiple ethnic groups - White and Black Caribbean',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2020-06-26T17:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-no-further-action',
#    'name': 'A no further action disposal'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'Black',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'},
#  {'age_range': 'under 10',
#   'outcome': 'Summons / charged by post',
#   'involved_person': True,
#   'self_defined_ethnicity': 'White - English/Welsh/Scottish/Northern Irish/British',
#   'gender': 'Male',
#   'legislation': 'Misuse of Drugs Act 1971 (section 23)',
#   'outcome_linked_to_object_of_search': True,
#   'datetime': '2020-06-30T14:00:00+00:00',
#   'removal_of_more_than_outer_clothing': False,
#   'outcome_object': {'id': 'bu-summons', 'name': 'Summons / charged by post'},
#   'location': {'latitude': '52.631569',
#    'street': {'id': 1489803, 'name': 'Leicester (Station)'},
#    'longitude': '-1.124283'},
#   'operation': None,
#   'officer_defined_ethnicity': 'White',
#   'type': 'Person search',
#   'operation_name': None,
#   'object_of_search': 'Controlled drugs'}]
